# %%
import json
import random
import time

TARGET_CLEAR = 5  # クリア必要フロア数
TOTAL_FLOORS = 8  # 有効な総フロア数

all_floors = random.sample(list(range(1, TOTAL_FLOORS + 1)), TARGET_CLEAR)
print(all_floors)
# Out:
# [6, 8, 5, 4, 1]
